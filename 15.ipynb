# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Fortune 500 Companies US.csv',encoding='latin1')

# %% [markdown]
# # Introduction to PANDAS
#
# Python has many powerful libraries like NUMPY ,scikit-learn,etc
# shape is attribute that tell how many rows and number of column.
# df.describe()
# *info() tell how many column.
# df.loc()=for particular column
# value_counts()   # count the unique value and arrange in way
# loc[]  #use for rows
# data.loc[0:11,['season','winner]]  # after comma we can find particular column.
# and iloc is used from index value.

# %%
data.loc[0:3]
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2     3               Apple            1,16,000            3.0  $2,15,639
# 3     4         Exxon Mobil              72,700            2.0  $2,05,004
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035
# 2          -7.7%  $45,687.0        -14.4%  $3,21,686    $7,53,718
# 3         -16.7%   $7,840.0        -51.5%  $3,30,314    $3,40,056

# %%
data.head(5)
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2     3               Apple            1,16,000            3.0  $2,15,639
# 3     4         Exxon Mobil              72,700            2.0  $2,05,004
# 4     5            McKesson              68,000            5.0  $1,92,487
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035
# 2          -7.7%  $45,687.0        -14.4%  $3,21,686    $7,53,718
# 3         -16.7%   $7,840.0        -51.5%  $3,30,314    $3,40,056
# 4           6.2%   $2,258.0         53.0%    $56,563      $31,439

# %%
import matplotlib.pyplot as plt

# %%
data.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Rank', 'Company Name', 'Number of Employees', 'Previous Rank',
#        'Revenues', 'Revenue Change', 'Profits', 'Profit Change', 'Assets',
#        'Market Value'],
#       dtype='object')

# %%
data.drop_duplicates(subset=['Rank'])
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
data.drop_duplicates('Number of Employees',keep='last').sort_values('Number of Employees',ascending=False).head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
data.drop_duplicates('Number of Employees',keep='last')
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 5       6  UnitedHealth Group            2,30,000            6.0  $1,84,840
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
data.drop_duplicates(subset=['Number of Employees','Rank'],keep='last')
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
data.drop_duplicates(subset=['Number of Employees','Rank'],keep='last').shape[0]
# Out:
# 500

# %%
data.drop_duplicates(subset=['Number of Employees','Rank'],keep='last').head(5).plot(kind='bar')
# Out:
# <Axes: >

# %%
data.drop_duplicates(subset=['Number of Employees','Rank'],keep='last').head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
data=pd.read_csv('fortune1000_2024.csv')

# %%
data.columns
# Out:
# Index(['Rank', 'Company', 'Ticker', 'Sector', 'Industry', 'Profitable',
#        'Founder_is_CEO', 'FemaleCEO', 'Growth_in_Jobs', 'Change_in_Rank',
#        'Gained_in_Rank', 'Dropped_in_Rank', 'Newcomer_to_the_Fortune500',
#        'Global500', 'Worlds_Most_Admired_Companies',
#        'Best_Companies_to_Work_For', 'Number_of_employees',
#        'MarketCap_March28_M', 'Revenues_M', 'RevenuePercentChange',
#        'Profits_M', 'ProfitsPercentChange', 'Assets_M', 'CEO', 'Country',
#        'HeadquartersCity', 'HeadquartersState', 'Website', 'CompanyType',
#        'Footnote', 'MarketCap_Updated_M', 'Updated'],
#       dtype='object')

# %%
data.shape[0]
# Out:
# 1000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           1000 non-null   int64
#  1   Company                        1000 non-null   object
#  2   Ticker                         959 non-null    object
#  3   Sector                         1000 non-null   object
#  4   Industry                       1000 non-null   object
#  5   Profitable                     1000 non-null   object
#  6   Founder_is_CEO                 1000 non-null   object
#  7   FemaleCEO                      1000 non-null   object
#  8   Growth_in_Jobs                 1000 non-null   object
#  9   Change_in_Rank                 1000 non-null   float64
#  10  Gained_in_Rank                 1000 non-null   object
#  11  Dropped_in_Rank                1000 non-null   object
# ...

# %%
data.describe()
# Out:
#               Rank  Change_in_Rank  Number_of_employees  MarketCap_March28_M  \
# count  1000.000000      1000.00000         1.000000e+03         9.590000e+02
# mean    500.498000         5.83800         3.661176e+04         5.083890e+04
# std     288.819686        66.88084         9.990100e+04         1.913577e+05
# min       1.000000      -577.00000         2.800000e+01         1.200000e+00
# 25%     250.750000       -14.00000         6.718000e+03         4.862750e+03
# 50%     500.500000         4.00000         1.400000e+04         1.253230e+04
# 75%     750.250000        30.25000         3.074075e+04         3.892385e+04
# max    1000.000000       420.00000         2.100000e+06         3.126133e+06
#
#           Revenues_M  RevenuePercentChange     Profits_M  \
# count    1000.000000            994.000000    998.000000
# mean    20965.064200              6.788129   1867.165832
# std     48589.311028             34.918519   6649.887738
# ...

# %%
data["Founder_is_CEO"].value_counts()
# Out:
# Founder_is_CEO
# no     937
# yes     63
# Name: count, dtype: int64

# %%
data["Company"].value_counts()
# Out:
# Company
# Walmart                         1
# Amazon                          1
# Apple                           1
# UnitedHealth Group              1
# Berkshire Hathaway              1
#                                ..
# Allegiant Travel                1
# Dropbox                         1
# Exact Sciences                  1
# BWX Technologies                1
# Clear Channel Outdoor Hldgs.    1
# Name: count, Length: 1000, dtype: int64

# %%
data["Number_of_employees"].value_counts()
# Out:
# Number_of_employees
# 18000     9
# 12000     8
# 20000     8
# 15000     7
# 9000      7
#          ..
# 7700      1
# 5300      1
# 71413     1
# 45600     1
# 221000    1
# Name: count, Length: 752, dtype: int64

# %%
data["Company"].unique()
# Out:
# array(['Walmart', 'Amazon', 'Apple', 'UnitedHealth Group',
#        'Berkshire Hathaway', 'CVS Health', 'Exxon Mobil', 'Alphabet',
#        'McKesson', 'Cencora', 'Costco Wholesale', 'JPMorgan Chase',
#        'Microsoft', 'Cardinal Health', 'Chevron', 'Cigna', 'Ford Motor',
#        'Bank of America', 'General Motors', 'Elevance Health',
#        'Citigroup', 'Centene', 'Home Depot', 'Marathon Petroleum',
#        'Kroger', 'Phillips 66', 'Fannie Mae', 'Walgreens Boots Alliance',
#        'Valero Energy', 'Meta Platforms', 'Verizon Communications',
#        'AT&T', 'Comcast', 'Wells Fargo', 'Goldman Sachs Group',
#        'Freddie Mac', 'Target', 'Humana', 'State Farm Insurance', 'Tesla',
#        'Morgan Stanley', 'Johnson & Johnson', 'Archer Daniels Midland',
#        'PepsiCo', 'United Parcel Service', 'FedEx', 'Walt Disney',
#        'Dell Technologies', "Lowe's", 'Procter & Gamble',
#        'Energy Transfer', 'Boeing', 'Albertsons', 'Sysco', 'RTX',
# ...

# %%
data.drop_duplicates(subset=['Company'])
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                        Amazon   AMZN            Retailing
# 2       3                         Apple   AAPL           Technology
# 3       4            UnitedHealth Group    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
data['Sector'].value_counts()
# Out:
# Sector
# Financials                       163
# Technology                       115
# Energy                           107
# Health Care                       80
# Retailing                         72
# Business Services                 59
# Industrials                       48
# Materials                         47
# Transportation                    39
# Food, Beverages & Tobacco         35
# Engineering & Construction        31
# Wholesalers                       30
# Hotels, Restaurants & Leisure     29
# Chemicals                         26
# Media                             26
# Motor Vehicles & Parts            21
# Household Products                20
# Aerospace & Defense               19
# Apparel                           15
# Food & Drug Stores                 9
# Telecommunications                 9
# Name: count, dtype: int64

# %%
data.info('Sector')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           1000 non-null   int64
#  1   Company                        1000 non-null   object
#  2   Ticker                         959 non-null    object
#  3   Sector                         1000 non-null   object
#  4   Industry                       1000 non-null   object
#  5   Profitable                     1000 non-null   object
#  6   Founder_is_CEO                 1000 non-null   object
#  7   FemaleCEO                      1000 non-null   object
#  8   Growth_in_Jobs                 1000 non-null   object
#  9   Change_in_Rank                 1000 non-null   float64
#  10  Gained_in_Rank                 1000 non-null   object
#  11  Dropped_in_Rank                1000 non-null   object
# ...

# %% [markdown]
# #📌 INTRODUCTION od GROPUBY

# %%
sectors=data.groupby("Sector")

# %%
data.groupby('Sector').count().head(4).plot(kind='bar')
# Out:
# <Axes: xlabel='Sector'>

# %%
data.groupby('Sector').count()
# Out:
# Sector
# Aerospace & Defense               19
# Apparel                           15
# Business Services                 59
# Chemicals                         26
# Energy                           107
# Engineering & Construction        31
# Financials                       163
# Food & Drug Stores                 9
# Food, Beverages & Tobacco         35
# Health Care                       80
# Hotels, Restaurants & Leisure     29
# Household Products                20
# Industrials                       48
# Materials                         47
# Media                             26
# Motor Vehicles & Parts            21
# Retailing                         72
# Technology                       115
# Telecommunications                 9
# Transportation                    39
# Wholesalers                       30
# dtype: int64

# %%
sectors.size().sort_values(ascending=False)  #company count in each sector
# Out:
# Sector
# Financials                       163
# Technology                       115
# Energy                           107
# Health Care                       80
# Retailing                         72
# Business Services                 59
# Industrials                       48
# Materials                         47
# Transportation                    39
# Food, Beverages & Tobacco         35
# Engineering & Construction        31
# Wholesalers                       30
# Hotels, Restaurants & Leisure     29
# Chemicals                         26
# Media                             26
# Motor Vehicles & Parts            21
# Household Products                20
# Aerospace & Defense               19
# Apparel                           15
# Food & Drug Stores                 9
# Telecommunications                 9
# dtype: int64

# %%
data.groupby('Sector')
print(len('sectors'))  # How many sectors are there?
# Out:
# 7

# %%
sectors.first()  #quick look at first entry in each sector
# Out:
#                                Rank                 Company Ticker  \
# Sector
# Aerospace & Defense              52                  Boeing     BA
# Apparel                          88                    Nike    NKE
# Business Services               135                    Visa      V
# Chemicals                        99                     Dow    DOW
# Energy                            7             Exxon Mobil    XOM
# Engineering & Construction      120             D.R. Horton    DHI
# Financials                        5      Berkshire Hathaway   BRKA
# Food & Drug Stores               25                  Kroger     KR
# Food, Beverages & Tobacco        43  Archer Daniels Midland    ADM
# Health Care                       4      UnitedHealth Group    UNH
# Hotels, Restaurants & Leisure   116               Starbucks   SBUX
# Household Products               50        Procter & Gamble     PG
# Industrials                      56        General Electric     GE
# ...

# %%
sectors.last()  #quick look at last entry in each sector
# Out:
#                                Rank                       Company Ticker  \
# Sector
# Aerospace & Defense             999              BWX Technologies   BWXT
# Apparel                         975                Kontoor Brands    KTB
# Business Services              1000  Clear Channel Outdoor Hldgs.    CCO
# Chemicals                       994                Mativ Holdings   MATV
# Energy                          986                  Talen Energy   TLNE
# Engineering & Construction      976              Skyline Champion    SKY
# Financials                      990               AGNC Investment   AGNC
# Food & Drug Stores              750        Grocery Outlet Holding     GO
# Food, Beverages & Tobacco       979                     Universal    UVV
# Health Care                     998                Exact Sciences   EXAS
# Hotels, Restaurants & Leisure   934           Peloton Interactive   PTON
# Household Products              896            Energizer Holdings    ENR
# ...

# %%
sectors.groups  #returns a dictionary mapping group names to row indices
#(labels) of the rows in the original DataFrame that belong to each group.
#company.iloc[51,:]
# Out:
# {'Aerospace & Defense': [51, 54, 56, 103, 108, 208, 307, 356, 532, 536, 564, 591, 607, 751, 841, 892, 906, 918, 998], 'Apparel': [87, 354, 424, 464, 530, 543, 556, 576, 589, 752, 800, 818, 872, 900, 974], 'Business Services': [134, 144, 163, 185, 198, 214, 218, 219, 227, 248, 275, 286, 287, 297, 328, 371, 409, 436, 460, 540, 546, 563, 567, 573, 603, 611, 624, 630, 640, 650, 654, 655, 690, 693, 701, 716, 722, 734, 765, 768, 780, 788, 795, 816, 834, 848, 877, 879, 916, 925, 949, 959, 960, 966, 984, 987, 991, 992, 999], 'Chemicals': [98, 133, 175, 225, 268, 306, 321, 325, 326, 355, 368, 411, 425, 491, 521, 534, 554, 566, 687, 758, 809, 813, 862, 955, 973, 993], 'Energy': [6, 14, 23, 25, 28, 50, 67, 89, 91, 92, 111, 136, 147, 148, 149, 151, 160, 162, 164, 166, 168, 176, 177, 186, 199, 211, 216, 229, 231, 243, 245, 249, 255, 267, 270, 282, 288, 301, 317, 318, 330, 338, 347, 348, 358, 370, 372, 377, 433, 434, 438, 439, 440, 441, 443, 448, 450, 453, 454, 477, 493, 509, 510, 526, 538, 574, 5
# ...

# %%
data.iloc[51,:]
# Out:
# Rank                                                            52
# Company                                                     Boeing
# Ticker                                                          BA
# Sector                                         Aerospace & Defense
# Industry                                       Aerospace & Defense
# Profitable                                                      no
# Founder_is_CEO                                                  no
# FemaleCEO                                                       no
# Growth_in_Jobs                                                 yes
# Change_in_Rank                                                 6.0
# Gained_in_Rank                                                 yes
# Dropped_in_Rank                                                 no
# Newcomer_to_the_Fortune500                                      no
# Global500                                                      yes
# ...

# %%
sectors.get_group('Energy')   #important #it removed sector column because it was unnecessary
# Out:
#      Rank                     Company Ticker  Sector  \
# 6       7                 Exxon Mobil    XOM  Energy
# 14     15                     Chevron    CVX  Energy
# 23     24          Marathon Petroleum    MPC  Energy
# 25     26                 Phillips 66    PSX  Energy
# 28     29               Valero Energy    VLO  Energy
# ..    ...                         ...    ...     ...
# 964   965                       Spire     SR  Energy
# 970   971             ProFrac Holding   ACDC  Energy
# 979   980               Consol Energy   CEIX  Energy
# 982   983  Alliance Resource Partners   ARLP  Energy
# 985   986                Talen Energy   TLNE  Energy
#
#                             Industry Profitable Founder_is_CEO FemaleCEO  \
# 6                 Petroleum Refining        yes             no        no
# 14                Petroleum Refining        yes             no        no
# 23                Petroleum Refining        yes             no        no
# ...

# %%
sectors.sum()
# Out:
#                                 Rank  \
# Sector
# Aerospace & Defense             9398
# Apparel                         9254
# Business Services              36048
# Chemicals                      13277
# Energy                         51310
# Engineering & Construction     17330
# Financials                     76599
# Food & Drug Stores              2864
# Food, Beverages & Tobacco      13224
# Health Care                    37624
# Hotels, Restaurants & Leisure  16758
# Household Products             10578
# Industrials                    27048
# Materials                      26413
# Media                          15643
# Motor Vehicles & Parts         10926
# Retailing                      30616
# Technology                     59773
# Telecommunications              2349
# Transportation                 20321
# Wholesalers                    13145
#
#                                                                          Company  \
# Sector
# ...

# %%
data.columns
# Out:
# Index(['Rank', 'Company', 'Ticker', 'Sector', 'Industry', 'Profitable',
#        'Founder_is_CEO', 'FemaleCEO', 'Growth_in_Jobs', 'Change_in_Rank',
#        'Gained_in_Rank', 'Dropped_in_Rank', 'Newcomer_to_the_Fortune500',
#        'Global500', 'Worlds_Most_Admired_Companies',
#        'Best_Companies_to_Work_For', 'Number_of_employees',
#        'MarketCap_March28_M', 'Revenues_M', 'RevenuePercentChange',
#        'Profits_M', 'ProfitsPercentChange', 'Assets_M', 'CEO', 'Country',
#        'HeadquartersCity', 'HeadquartersState', 'Website', 'CompanyType',
#        'Footnote', 'MarketCap_Updated_M', 'Updated'],
#       dtype='object')

# %%
sectors[['Revenues_M']].mean().sort_values(by='Revenues_M',ascending=False)
# Out:
#                                  Revenues_M
# Sector
# Telecommunications             53811.300000
# Food & Drug Stores             52199.144444
# Health Care                    38810.416250
# Retailing                      36809.552778
# Motor Vehicles & Parts         29126.728571
# Financials                     22917.158282
# Energy                         21398.438318
# Technology                     21051.257391
# Aerospace & Defense            20487.405263
# Food, Beverages & Tobacco      19923.931429
# Wholesalers                    17087.440000
# Transportation                 15684.705128
# Media                          12592.030769
# Industrials                    11961.085417
# Household Products             11863.860000
# Chemicals                      10997.780769
# Engineering & Construction      9316.077419
# Apparel                         8706.613333
# Hotels, Restaurants & Leisure   8590.865517
# Materials                       8561.502128
# ...

# %% [markdown]
# # New Dataset

# %%
data=pd.read_csv('deliveries.csv')

# %%
data.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  object
#  3   bowling_team      150460 non-null  object
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  object
#  7   non_striker       150460 non-null  object
#  8   bowler            150460 non-null  object
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...
