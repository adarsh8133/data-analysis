# %%
# !import pandas as pd
# Out:
# 'import' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
data=pd.read_csv("matches - matches.csv")

# %%
print("hello")
# Out:
# hello

# %%
data[['win_by_wickets']].value_counts()
# Out:
# win_by_wickets
# 0                 297
# 7                  70
# 6                  68
# 5                  57
# 8                  48
# 4                  34
# 9                  32
# 3                  15
# 10                 10
# 2                   4
# 1                   1
# Name: count, dtype: int64

# %%
data.loc[0:3,['team1','team2','city']]
# Out:
#                     team1                        team2       city
# 0     Sunrisers Hyderabad  Royal Challengers Bangalore  Hyderabad
# 1          Mumbai Indians       Rising Pune Supergiant       Pune
# 2           Gujarat Lions        Kolkata Knight Riders     Rajkot
# 3  Rising Pune Supergiant              Kings XI Punjab     Indore

# %%
data.loc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.loc[600]
# Out:
# id                                                     601
# season                                                2016
# city                                                  Pune
# date                                            2016-04-29
# team1                              Rising Pune Supergiants
# team2                                        Gujarat Lions
# toss_winner                                  Gujarat Lions
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                                       Gujarat Lions
# win_by_runs                                              0
# win_by_wickets                                           3
# player_of_match                                   DR Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                        CB Gaffaney
# ...

# %%
len(data.loc[0])
# Out:
# 18

# %%
data.loc[:,["city"]]
# Out:
#           city
# 0    Hyderabad
# 1         Pune
# 2       Rajkot
# 3       Indore
# 4    Bangalore
# ..         ...
# 631     Raipur
# 632  Bangalore
# 633      Delhi
# 634      Delhi
# 635  Bangalore
#
# [636 rows x 1 columns]

# %%
data.loc[:,]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.loc[512:522,['team1','team2','city','winner']]
# Out:
#                      team1                        team2       city  \
# 512       Rajasthan Royals               Mumbai Indians     Mumbai
# 513  Kolkata Knight Riders              Kings XI Punjab    Kolkata
# 514         Mumbai Indians          Chennai Super Kings     Mumbai
# 515        Kings XI Punjab          Chennai Super Kings     Mumbai
# 516        Kings XI Punjab        Kolkata Knight Riders  Bangalore
# 517         Mumbai Indians        Kolkata Knight Riders    Kolkata
# 518    Chennai Super Kings             Delhi Daredevils    Chennai
# 519       Rajasthan Royals              Kings XI Punjab       Pune
# 520    Chennai Super Kings          Sunrisers Hyderabad    Chennai
# 521  Kolkata Knight Riders  Royal Challengers Bangalore    Kolkata
# 522       Delhi Daredevils             Rajasthan Royals      Delhi
#
#                           winner
# 512               Mumbai Indians
# 513        Kolkata Knight Riders
# 514          Chennai Super Kings
# ...

# %%
data.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data.iloc[:,[5,4,10]]
# Out:
#                            team2                        team1  \
# 0    Royal Challengers Bangalore          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4               Delhi Daredevils  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633        Kolkata Knight Riders          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
data["city"]
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %%
data['city']=='Hyderabad'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
mask=data['city']=='Hyderabad'
data[mask]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
mask=data['team1']=='Sunrisers Hyderabad'
data[mask]
# Out:
#       id  season           city        date                team1  \
# 0      1    2017      Hyderabad  2017-04-05  Sunrisers Hyderabad
# 9     10    2017         Mumbai  2017-04-12  Sunrisers Hyderabad
# 18    19    2017      Hyderabad  2017-04-17  Sunrisers Hyderabad
# 20    21    2017      Hyderabad  2017-04-19  Sunrisers Hyderabad
# 24    25    2017           Pune  2017-04-22  Sunrisers Hyderabad
# 31    32    2017     Chandigarh  2017-04-28  Sunrisers Hyderabad
# 35    36    2017      Hyderabad  2017-04-30  Sunrisers Hyderabad
# 38    39    2017          Delhi  2017-05-02  Sunrisers Hyderabad
# 56    57    2017      Bangalore  2017-05-17  Sunrisers Hyderabad
# 383  384    2013      Hyderabad  2013-04-05  Sunrisers Hyderabad
# 401  402    2013           Pune  2013-04-17  Sunrisers Hyderabad
# 413  414    2013        Chennai  2013-04-25  Sunrisers Hyderabad
# 415  416    2013         Jaipur  2013-04-27  Sunrisers Hyderabad
# ...

# %%
def xyz(city):
    mask=data['team1']=='Sunrisers Hyderabad'
    return data[mask].shape[0]
xyz(' Sunrisers Hyderabad')
# Out:
# 46

# %%
def xyz(a):
    mask=data['team1']==a
    return data[mask].shape[0]

# %%
xyz('Chennai Super Kings')
# Out:
# 77
